# %% [markdown]
# # Using logical and comparison operators
# © ExploreAI Academy

# %% [markdown]
# > ⚠️ This notebook will not run on Google Colab because it cannot connect to a local database. Please make sure that this notebook is running on the same local machine as your MySQL Workbench installation and MySQL `united_nations` database.

# %% [markdown]
# ## Learning Objectives
#
# - Understand the concept of logic and comparison operators in SQL.
# - Learn how to use the WHERE clause to filter data based on specific conditions.
# - Understand the use of IN, BETWEEN, and other SQL operators to streamline queries.

# %% [markdown]
# ## Overview
#
# In this notebook, we will explore the use of logic and comparison operators in SQL to filter and extract specific data from a dataset. These operators are essential tools in SQL that allow us to narrow down our data based on certain conditions.
#
# We will be working with the `united_nations.Access_to_Basic_Services` table, which contains information about different countries, their GDP, access to basic services, and more.

# %% [markdown]
# ### Connecting to our MySQL database
#
# Since we have a MySQL database, we can connect to it using mysql and pymysql.

# %%
# load and activate the SQL extension to allows us to execute SQL in a Jupyter notebook

# %load_ext sql

# %%
# establish a connection to the local database using the '%sql' magic command,
# replace 'password' with our connection password and `db_name` with our database name

# %sql mysql+pymysql://root:paschalugwu@localhost:3306/united_nations

# %% [markdown]
# ## Exercise
#
# ### Task 1: Basic Filtering with Comparison Operators
#
# You will be working with the `united_nations.Access_to_Basic_Services` table.
# The columns to `SELECT` include
# - `Country_name`
# - `Time_period`
# - `Pct_managed_drinking_water_services`
# - `Pct_managed_sanitation_services`
# - `Est_population_in_millions`
# - and `Est_gdp_in_billions`
#
#
# Use the `WHERE` clause to filter out records of specific countries:
# - `Nigeria`,
# - `Ethiopia`,
# - `Congo`,
# - `Egypt`,
# - `Tanzania`,
# - `Kenya`,
# - and `South Africa`
# - for the time period between `2019` and `2020`.
# Utilize the `OR` operator to include multiple countries in your filter.

# %%
# %%sql
# -- Add your code here
# SELECT Country_name, Time_period, Pct_managed_drinking_water_services, Pct_managed_sanitation_services, Est_population_in_millions, Est_gdp_in_billions
# FROM united_nations.Access_to_Basic_Services
# WHERE Country_name IN ('Nigeria'OR 'Ethiopia'OR 'Congo'OR 'Egypt'OR 'Tanzania'OR 'Kenya'OR 'South Africa')
# AND Time_period BETWEEN 2019 AND 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 334 rows affected.
# [('Kazakhstan', 2019, Decimal('95.00'), Decimal('98.00'), Decimal('18.513673'), Decimal('181.67')),
#  ('Kazakhstan', 2020, Decimal('95.00'), Decimal('98.00'), Decimal('18.755666'), Decimal('171.08')),
#  ('Kyrgyzstan', 2019, Decimal('91.67'), Decimal('97.33'), None, None),
#  ('Kyrgyzstan', 2020, Decimal('92.67'), Decimal('97.67'), None, None),
#  ('Tajikistan', 2019, Decimal('85.00'), Decimal('96.33'), Decimal('9.337003'), Decimal('8.30')),
#  ('Tajikistan', 2020, Decimal('85.00'), Decimal('96.33'), Decimal('9.543207'), Decimal('8.13')),
#  ('Turkmenistan', 2019, Decimal('100.00'), Decimal('99.33'), Decimal('6.158420'), Decimal('45.23')),
#  ('Turkmenistan', 2020, Decimal('100.00'), Decimal('99.33'), Decimal('6.250438'), None),
#  ('Uzbekistan', 2019, Decimal('98.00'), Decimal('100.00'), Decimal('33.580350'), Decimal('59.91')),
#  ('Uzbekistan', 2020, Decimal('98.00'), Decimal('100.00'), Decimal('34.232050'), Decimal('59.89')),
#  ('Afghanistan', 2019, Decimal('78.00'), Decimal('52.33'), Decimal('37.769499'), Decimal('18.90')),
#  ('Afghanistan', 2020, Decimal('80.33'), Decimal('54.00'), Decimal('38.972230'), Decimal('20.14')),
#  ('Bangladesh', 2019, Decimal('97.67'), Decimal('52.67'), Decimal('165.516222'), Decimal('351.24')),
#  ('Bangladesh', 2020, Decimal('97.67'), Decimal('54.00'), Decimal('167.420951'), Decimal('373.90')),
#  ('Bhutan', 2019, Decimal('97.33'), Decimal('75.00'), Decimal('0.767459'), Decimal('2.54')),
#  ('Bhutan', 2020, Decimal('97.33'), Decimal('76.67'), Decimal('0.772506'), Decimal('2.33')),
#  ('India', 2019, Decimal('90.67'), Decimal('69.67'), Decimal('1383.112050'), Decimal('2831.55')),
#  ('India', 2020, Decimal('91.00'), Decimal('72.33'), Decimal('1396.387127'), Decimal('2667.69')),
#  ('Iran (Islamic Republic of)', 2019, Decimal('96.33'), Decimal('88.33'), None, None),
#  ('Iran (Islamic Republic of)', 2020, Decimal('96.67'), Decimal('88.33'), None, None),
#  ('Maldives', 2019, Decimal('99.67'), Decimal('98.33'), Decimal('0.504508'), Decimal('5.61')),
#  ('Maldives', 2020, Decimal('99.67'), Decimal('99.33'), Decimal('0.514438'), Decimal('3.75')),
#  ('Nepal', 2019, Decimal('90.00'), Decimal('73.33'), Decimal('28.832496'), Decimal('34.19')),
#  ('Nepal', 2020, Decimal('90.00'), Decimal('76.67'), Decimal('29.348627'), Decimal('33.43')),
#  ('Pakistan', 2019, Decimal('90.33'), Decimal('68.67'), Decimal('223.293280'), Decimal('320.91')),
#  ('Pakistan', 2020, Decimal('90.67'), Decimal('70.00'), Decimal('227.196741'), Decimal('300.43')),
#  ('Sri Lanka', 2019, Decimal('94.33'), Decimal('93.67'), Decimal('21.803000'), Decimal('89.01')),
#  ('Sri Lanka', 2020, Decimal('94.33'), Decimal('93.67'), Decimal('21.919000'), Decimal('85.35')),
#  ('China', 2019, Decimal('93.33'), Decimal('90.33'), Decimal('1407.745000'), Decimal('14279.94')),
#  ('China', 2020, Decimal('93.67'), Decimal('91.67'), Decimal('1411.100000'), Decimal('14687.67')),
#  ("Democratic People's Republic of Korea", 2019, Decimal('93.33'), Decimal('83.33'), None, None),
#  ("Democratic People's Republic of Korea", 2020, Decimal('93.33'), Decimal('83.33'), None, None),
#  ('Japan', 2019, Decimal('99.00'), Decimal('100.00'), Decimal('126.633000'), Decimal('5123.32')),
#  ('Japan', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('126.261000'), Decimal('5040.11')),
#  ('Mongolia', 2019, Decimal('80.00'), Decimal('63.67'), Decimal('3.232430'), Decimal('14.21')),
#  ('Mongolia', 2020, Decimal('81.00'), Decimal('65.00'), Decimal('3.294335'), Decimal('13.31')),
#  ('Republic of Korea', 2019, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Republic of Korea', 2020, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Brunei Darussalam', 2019, Decimal('100.00'), None, Decimal('0.438048'), Decimal('13.47')),
#  ('Brunei Darussalam', 2020, Decimal('100.00'), None, Decimal('0.441725'), Decimal('12.01')),
#  ('Cambodia', 2019, Decimal('75.33'), Decimal('71.67'), Decimal('16.207746'), Decimal('27.09')),
#  ('Cambodia', 2020, Decimal('75.33'), Decimal('74.33'), Decimal('16.396860'), Decimal('25.87')),
#  ('Indonesia', 2019, Decimal('91.33'), Decimal('83.33'), Decimal('269.582878'), Decimal('1119.10')),
#  ('Indonesia', 2020, Decimal('92.00'), Decimal('86.00'), Decimal('271.857970'), Decimal('1058.69')),
#  ("Lao People's Democratic Republic", 2019, Decimal('86.67'), Decimal('82.00'), None, None),
#  ("Lao People's Democratic Republic", 2020, Decimal('86.67'), Decimal('82.00'), None, None),
#  ('Malaysia', 2019, Decimal('95.33'), Decimal('100.00'), Decimal('32.804020'), Decimal('365.18')),
#  ('Malaysia', 2020, Decimal('95.33'), Decimal('100.00'), Decimal('33.199993'), Decimal('337.34')),
#  ('Myanmar', 2019, Decimal('84.00'), Decimal('74.00'), Decimal('53.040212'), Decimal('68.70')),
#  ('Myanmar', 2020, Decimal('85.67'), Decimal('74.67'), Decimal('53.423198'), Decimal('78.93')),
#  ('Philippines', 2019, Decimal('93.67'), Decimal('81.00'), Decimal('110.380804'), Decimal('376.82')),
#  ('Philippines', 2020, Decimal('94.00'), Decimal('82.00'), Decimal('112.190977'), Decimal('361.75')),
#  ('Singapore', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('5.703569'), Decimal('375.47')),
#  ('Singapore', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('5.685807'), Decimal('345.30')),
#  ('Thailand', 2019, Decimal('100.00'), Decimal('98.33'), Decimal('71.307763'), Decimal('544.08')),
#  ('Thailand', 2020, Decimal('100.00'), Decimal('98.67'), Decimal('71.475664'), Decimal('499.68')),
#  ('Timor-Leste', 2019, Decimal('86.00'), Decimal('59.00'), Decimal('1.280438'), Decimal('2.03')),
#  ('Timor-Leste', 2020, Decimal('87.00'), Decimal('60.00'), Decimal('1.299995'), Decimal('2.16')),
#  ('Viet Nam', 2019, Decimal('96.67'), Decimal('89.00'), None, None),
#  ('Viet Nam', 2020, Decimal('97.33'), Decimal('90.00'), None, None),
#  ('Bermuda', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('0.063911'), Decimal('7.42')),
#  ('Bermuda', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.063893'), Decimal('6.89')),
#  ('Canada', 2019, Decimal('99.00'), Decimal('99.00'), Decimal('37.601230'), Decimal('1742.02')),
#  ('Canada', 2020, Decimal('99.00'), Decimal('99.00'), Decimal('38.037204'), Decimal('1645.42')),
#  ('Greenland', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('0.056225'), Decimal('2.99')),
#  ('Greenland', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('0.056367'), Decimal('3.08')),
#  ('Saint Pierre and Miquelon', 2019, Decimal('91.00'), Decimal('100.00'), None, None),
#  ('Saint Pierre and Miquelon', 2020, Decimal('91.00'), Decimal('100.00'), None, None),
#  ('United States of America', 2019, Decimal('99.67'), Decimal('99.67'), None, None),
#  ('United States of America', 2020, Decimal('100.00'), Decimal('99.67'), None, None),
#  ('Bahamas', 2019, Decimal('99.00'), Decimal('95.00'), None, None),
#  ('Barbados', 2019, Decimal('99.00'), Decimal('98.00'), Decimal('0.280180'), Decimal('5.32')),
#  ('Barbados', 2020, Decimal('99.00'), Decimal('98.00'), Decimal('0.280693'), Decimal('4.67')),
#  ('British Virgin Islands', 2019, Decimal('100.00'), None, Decimal('0.030610'), None),
#  ('British Virgin Islands', 2020, Decimal('100.00'), None, Decimal('0.030910'), None),
#  ('Cuba', 2019, Decimal('96.33'), Decimal('90.00'), Decimal('11.316697'), Decimal('103.43')),
#  ('Cuba', 2020, Decimal('96.33'), Decimal('90.00'), Decimal('11.300698'), Decimal('107.35')),
#  ('Dominican Republic', 2019, Decimal('95.00'), Decimal('84.33'), Decimal('10.881882'), Decimal('88.94')),
#  ('Dominican Republic', 2020, Decimal('95.00'), Decimal('84.33'), Decimal('10.999664'), Decimal('78.84')),
#  ('Guadeloupe', 2019, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Guadeloupe', 2020, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Haiti', 2019, Decimal('64.67'), Decimal('36.00'), Decimal('11.160438'), Decimal('14.79')),
#  ('Haiti', 2020, Decimal('65.00'), Decimal('36.00'), Decimal('11.306801'), Decimal('14.51')),
#  ('Jamaica', 2019, Decimal('90.33'), Decimal('87.00'), Decimal('2.813773'), Decimal('15.83')),
#  ('Jamaica', 2020, Decimal('90.33'), Decimal('87.00'), Decimal('2.820436'), Decimal('13.81')),
#  ('Martinique', 2019, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Martinique', 2020, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Montserrat', 2019, Decimal('98.00'), Decimal('89.00'), None, None),
#  ('Montserrat', 2020, Decimal('98.00'), Decimal('89.00'), None, None),
#  ('Puerto Rico', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('3.193694'), Decimal('105.13')),
#  ('Puerto Rico', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('3.281538'), Decimal('103.02')),
#  ('Saint Barthélemy', 2019, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Saint Barthélemy', 2020, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Saint Lucia', 2019, Decimal('97.00'), Decimal('82.00'), None, None),
#  ('Saint Lucia', 2020, Decimal('97.00'), Decimal('82.00'), None, None),
#  ('Saint Martin (French Part)', 2019, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Saint Martin (French Part)', 2020, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Trinidad and Tobago', 2019, Decimal('99.00'), Decimal('94.00'), Decimal('1.519955'), Decimal('23.85')),
#  ('Trinidad and Tobago', 2020, Decimal('99.00'), Decimal('94.00'), Decimal('1.518147'), Decimal('21.06')),
#  ('United States Virgin Islands', 2019, Decimal('99.00'), Decimal('99.00'), None, None),
#  ('United States Virgin Islands', 2020, Decimal('99.00'), Decimal('99.00'), None, None),
#  ('Belize', 2019, Decimal('98.33'), Decimal('88.67'), Decimal('0.389095'), Decimal('2.42')),
#  ('Belize', 2020, Decimal('98.33'), Decimal('88.67'), Decimal('0.394921'), Decimal('2.08')),
#  ('Costa Rica', 2019, Decimal('100.00'), Decimal('97.33'), Decimal('5.084532'), Decimal('64.42')),
#  ('Costa Rica', 2020, Decimal('100.00'), Decimal('97.67'), Decimal('5.123105'), Decimal('62.16')),
#  ('El Salvador', 2019, Decimal('97.00'), Decimal('80.33'), Decimal('6.280217'), Decimal('26.88')),
#  ('El Salvador', 2020, Decimal('97.00'), Decimal('79.67'), Decimal('6.292731'), Decimal('24.56')),
#  ('Guatemala', 2019, Decimal('94.00'), Decimal('67.67'), Decimal('16.604026'), Decimal('77.17')),
#  ('Guatemala', 2020, Decimal('94.00'), Decimal('67.67'), Decimal('16.858333'), Decimal('77.63')),
#  ('Honduras', 2019, Decimal('94.67'), Decimal('82.67'), Decimal('9.958829'), Decimal('25.09')),
#  ('Honduras', 2020, Decimal('95.33'), Decimal('83.33'), Decimal('10.121763'), Decimal('23.83')),
#  ('Mexico', 2019, Decimal('98.67'), Decimal('90.00'), Decimal('125.085311'), Decimal('1269.01')),
#  ('Mexico', 2020, Decimal('99.33'), Decimal('90.67'), Decimal('125.998302'), Decimal('1090.52')),
#  ('Nicaragua', 2019, Decimal('79.33'), Decimal('71.67'), Decimal('6.663924'), Decimal('12.60')),
#  ('Nicaragua', 2020, Decimal('79.33'), Decimal('71.67'), Decimal('6.755895'), Decimal('12.59')),
#  ('Panama', 2019, Decimal('92.67'), Decimal('79.67'), Decimal('4.232532'), Decimal('66.98')),
#  ('Panama', 2020, Decimal('92.67'), Decimal('81.00'), Decimal('4.294396'), Decimal('53.98')),
#  ('Argentina', 2019, Decimal('100.00'), Decimal('98.00'), Decimal('44.938712'), Decimal('447.75')),
#  ('Argentina', 2020, Decimal('100.00'), Decimal('99.00'), Decimal('45.376763'), Decimal('385.54')),
#  ('Bolivia (Plurinational State of)', 2019, Decimal('90.33'), Decimal('59.67'), None, None),
#  ('Bolivia (Plurinational State of)', 2020, Decimal('90.67'), Decimal('61.67'), None, None),
#  ('Brazil', 2019, Decimal('97.33'), Decimal('81.67'), Decimal('211.782878'), Decimal('1873.27')),
#  ('Brazil', 2020, Decimal('98.33'), Decimal('82.33'), Decimal('213.196304'), Decimal('1448.56')),
#  ('Chile', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('19.039485'), Decimal('278.58')),
#  ('Chile', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('19.300315'), Decimal('252.73')),
#  ('Colombia', 2019, Decimal('94.33'), Decimal('90.33'), Decimal('50.187406'), Decimal('323.11')),
#  ('Colombia', 2020, Decimal('94.67'), Decimal('91.33'), Decimal('50.930662'), Decimal('270.30')),
#  ('Ecuador', 2019, Decimal('93.67'), Decimal('90.00'), Decimal('17.343740'), Decimal('108.11')),
#  ('Ecuador', 2020, Decimal('94.00'), Decimal('91.33'), Decimal('17.588595'), Decimal('99.29')),
#  ('Falkland Islands (Malvinas)', 2019, Decimal('91.00'), Decimal('100.00'), None, None),
#  ('Falkland Islands (Malvinas)', 2020, Decimal('91.00'), Decimal('100.00'), None, None),
#  ('French Guiana', 2019, Decimal('94.00'), Decimal('92.00'), None, None),
#  ('French Guiana', 2020, Decimal('94.00'), Decimal('92.00'), None, None),
#  ('Guyana', 2019, Decimal('96.67'), Decimal('87.33'), Decimal('0.798753'), Decimal('5.17')),
#  ('Guyana', 2020, Decimal('96.67'), Decimal('87.33'), Decimal('0.797202'), Decimal('5.47')),
#  ('Paraguay', 2019, Decimal('99.67'), Decimal('91.33'), Decimal('6.530026'), Decimal('37.93')),
#  ('Paraguay', 2020, Decimal('99.67'), Decimal('92.00'), Decimal('6.618695'), Decimal('35.43')),
#  ('Peru', 2019, Decimal('89.33'), Decimal('73.33'), Decimal('32.824861'), Decimal('228.32')),
#  ('Peru', 2020, Decimal('90.33'), Decimal('74.33'), Decimal('33.304756'), Decimal('201.71')),
#  ('Suriname', 2019, Decimal('97.33'), Decimal('87.67'), Decimal('0.600301'), Decimal('4.02')),
#  ('Suriname', 2020, Decimal('98.00'), Decimal('88.67'), Decimal('0.607065'), Decimal('2.91')),
#  ('Uruguay', 2019, Decimal('98.00'), Decimal('98.00'), Decimal('3.428409'), Decimal('61.23')),
#  ('Uruguay', 2020, Decimal('98.00'), Decimal('98.33'), Decimal('3.429086'), Decimal('53.56')),
#  ('Venezuela (Bolivarian Republic of)', 2019, Decimal('94.00'), Decimal('96.00'), None, None),
#  ('Venezuela (Bolivarian Republic of)', 2020, Decimal('94.00'), Decimal('96.00'), None, None),
#  ('Algeria', 2019, Decimal('93.33'), Decimal('84.67'), Decimal('42.705368'), Decimal('171.77')),
#  ('Algeria', 2020, Decimal('93.33'), Decimal('84.33'), Decimal('43.451666'), Decimal('145.01')),
#  ('Egypt', 2019, Decimal('99.33'), Decimal('97.00'), None, None),
#  ('Egypt', 2020, Decimal('99.33'), Decimal('97.67'), None, None),
#  ('Libya', 2019, Decimal('100.00'), Decimal('92.00'), Decimal('6.569088'), Decimal('69.25')),
#  ('Libya', 2020, Decimal('100.00'), Decimal('92.00'), Decimal('6.653942'), Decimal('50.36')),
#  ('Morocco', 2019, Decimal('87.33'), Decimal('84.00'), Decimal('36.304408'), Decimal('128.92')),
#  ('Morocco', 2020, Decimal('88.33'), Decimal('84.67'), Decimal('36.688772'), Decimal('121.35')),
#  ('Sudan', 2019, Decimal('62.33'), Decimal('40.33'), Decimal('43.232093'), Decimal('32.34')),
#  ('Sudan', 2020, Decimal('62.33'), Decimal('40.33'), Decimal('44.440486'), Decimal('27.03')),
#  ('Tunisia', 2019, Decimal('96.00'), Decimal('95.67'), Decimal('12.049314'), Decimal('41.91')),
#  ('Tunisia', 2020, Decimal('97.00'), Decimal('97.33'), Decimal('12.161723'), Decimal('42.54')),
#  ('Armenia', 2019, Decimal('100.00'), Decimal('92.33'), Decimal('2.820602'), Decimal('13.62')),
#  ('Armenia', 2020, Decimal('100.00'), Decimal('92.33'), Decimal('2.805608'), Decimal('12.64')),
#  ('Azerbaijan', 2019, Decimal('95.00'), Decimal('96.00'), Decimal('10.024283'), Decimal('48.17')),
#  ('Azerbaijan', 2020, Decimal('95.67'), Decimal('96.00'), Decimal('10.093121'), Decimal('42.69')),
#  ('Bahrain', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('1.494188'), Decimal('38.65')),
#  ('Bahrain', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('1.477469'), Decimal('34.72')),
#  ('Cyprus', 2019, Decimal('100.00'), Decimal('99.33'), Decimal('1.228836'), Decimal('25.94')),
#  ('Cyprus', 2020, Decimal('100.00'), Decimal('99.33'), Decimal('1.237537'), Decimal('25.01')),
#  ('Georgia', 2019, Decimal('96.67'), Decimal('84.67'), Decimal('3.720161'), Decimal('17.47')),
#  ('Georgia', 2020, Decimal('96.67'), Decimal('84.33'), Decimal('3.722716'), Decimal('15.84')),
#  ('Iraq', 2019, Decimal('97.00'), Decimal('99.33'), Decimal('41.563520'), Decimal('233.64')),
#  ('Iraq', 2020, Decimal('97.67'), Decimal('100.00'), Decimal('42.556984'), Decimal('184.37')),
#  ('Israel', 2019, Decimal('100.00'), Decimal('99.67'), Decimal('9.054000'), Decimal('402.47')),
#  ('Israel', 2020, Decimal('100.00'), Decimal('99.67'), Decimal('9.215100'), Decimal('413.27')),
#  ('Jordan', 2019, Decimal('98.33'), Decimal('96.33'), Decimal('10.698683'), Decimal('44.99')),
#  ('Jordan', 2020, Decimal('98.33'), Decimal('96.33'), Decimal('10.928721'), Decimal('44.18')),
#  ('Kuwait', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('4.441100'), Decimal('136.20')),
#  ('Kuwait', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('4.360444'), Decimal('105.96')),
#  ('Lebanon', 2019, Decimal('93.00'), Decimal('99.00'), Decimal('5.781907'), Decimal('51.95')),
#  ('Lebanon', 2020, Decimal('93.00'), Decimal('99.00'), Decimal('5.662923'), Decimal('31.71')),
#  ('Oman', 2019, Decimal('87.67'), Decimal('99.00'), Decimal('4.602768'), Decimal('88.06')),
#  ('Oman', 2020, Decimal('87.67'), Decimal('99.00'), Decimal('4.543399'), Decimal('75.91')),
#  ('Qatar', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('2.807235'), Decimal('175.84')),
#  ('Qatar', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('2.760385'), Decimal('144.41')),
#  ('Saudi Arabia', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('35.827362'), Decimal('803.62')),
#  ('Saudi Arabia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('35.997107'), Decimal('703.37')),
#  ('State of Palestine', 2019, Decimal('97.67'), Decimal('97.67'), None, None),
#  ('State of Palestine', 2020, Decimal('98.33'), Decimal('98.67'), None, None),
#  ('Syrian Arab Republic', 2019, Decimal('93.67'), Decimal('90.00'), Decimal('20.098251'), Decimal('22.44')),
#  ('Syrian Arab Republic', 2020, Decimal('93.67'), Decimal('90.00'), Decimal('20.772595'), Decimal('11.08')),
#  ('Türkiye', 2019, Decimal('96.67'), Decimal('98.33'), None, None),
#  ('Türkiye', 2020, Decimal('96.67'), Decimal('98.67'), None, None),
#  ('United Arab Emirates', 2019, Decimal('100.00'), Decimal('99.00'), Decimal('9.211657'), Decimal('417.99')),
#  ('United Arab Emirates', 2020, Decimal('100.00'), Decimal('99.00'), Decimal('9.287289'), Decimal('349.47')),
#  ('Yemen', 2019, Decimal('62.33'), Decimal('57.00'), None, None),
#  ('Yemen', 2020, Decimal('63.00'), Decimal('57.33'), None, None),
#  ('Australia', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('25.340217'), Decimal('1392.23')),
#  ('Australia', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('25.655289'), Decimal('1326.90')),
#  ('New Zealand', 2019, Decimal('100.00'), Decimal('100.00'), Decimal('4.979200'), Decimal('213.43')),
#  ('New Zealand', 2020, Decimal('100.00'), Decimal('100.00'), Decimal('5.090200'), Decimal('211.73')),
#  ('Fiji', 2019, Decimal('93.67'), Decimal('99.00'), Decimal('0.918465'), Decimal('5.48')),
#  ('Fiji', 2020, Decimal('93.67'), Decimal('99.00'), Decimal('0.920422'), Decimal('4.48')),
#  ('New Caledonia', 2019, Decimal('99.00'), Decimal('100.00'), Decimal('0.271230'), Decimal('9.44')),
#  ('New Caledonia', 2020, Decimal('99.00'), Decimal('100.00'), Decimal('0.271130'), Decimal('9.44')),
#  ('Papua New Guinea', 2019, Decimal('56.33'), Decimal('27.67'), Decimal('9.542486'), Decimal('24.75')),
#  ('Papua New Guinea', 2020, Decimal('56.67'), Decimal('27.67'), Decimal('9.749640'), Decimal('23.85')),
#  ('Solomon Islands', 2019, Decimal('72.33'), Decimal('44.33'), Decimal('0.674993'), Decimal('1.62')),
#  ('Solomon Islands', 2020, Decimal('72.33'), Decimal('44.67'), Decimal('0.691191'), Decimal('1.54')),
#  ('Vanuatu', 2019, Decimal('93.00'), Decimal('55.67'), Decimal('0.304404'), Decimal('0.94')),
#  ('Vanuatu', 2020, Decimal('93.00'), Decimal('55.67'), Decimal('0.311685'), Decimal('0.90')),
#  ('Guam', 2019, Decimal('100.00'), None, Decimal('0.168624'), Decimal('6.37')),
#  ('Guam', 2020, Decimal('100.00'), None, Decimal('0.169231'), Decimal('5.89')),
#  ('Kiribati', 2019, Decimal('76.00'), Decimal('44.67'), Decimal('0.124241'), Decimal('0.18')),
#  ('Kiribati', 2020, Decimal('77.00'), Decimal('45.33'), Decimal('0.126463'), Decimal('0.18')),
#  ('Marshall Islands', 2019, Decimal('90.00'), Decimal('78.00'), Decimal('0.044728'), Decimal('0.23')),
#  ('Marshall Islands', 2020, Decimal('90.00'), Decimal('78.00'), Decimal('0.043413'), Decimal('0.24')),
#  ('Micronesia (Federated States of)', 2019, Decimal('88.00'), Decimal('88.00'), None, None),
#  ('Nauru', 2019, Decimal('100.00'), None, Decimal('0.012132'), Decimal('0.12')),
#  ('Nauru', 2020, Decimal('100.00'), None, Decimal('0.012315'), Decimal('0.11')),
#  ('Northern Mariana Islands', 2019, Decimal('100.00'), Decimal('79.00'), Decimal('0.049858'), Decimal('1.18')),
#  ('Northern Mariana Islands', 2020, Decimal('100.00'), Decimal('79.00'), Decimal('0.049587'), None),
#  ('Palau', 2019, Decimal('100.00'), Decimal('99.67'), Decimal('0.017916'), Decimal('0.28')),
#  ('Palau', 2020, Decimal('100.00'), Decimal('99.67'), Decimal('0.017972'), Decimal('0.25')),
#  ('American Samoa', 2019, Decimal('100.00'), Decimal('54.00'), Decimal('0.047321'), Decimal('0.65')),
#  ('American Samoa', 2020, Decimal('100.00'), Decimal('54.00'), Decimal('0.046189'), Decimal('0.72')),
#  ('Cook Islands', 2019, Decimal('100.00'), Decimal('99.00'), None, None),
#  ('Cook Islands', 2020, Decimal('100.00'), Decimal('99.00'), None, None),
#  ('French Polynesia', 2019, Decimal('100.00'), Decimal('97.00'), Decimal('0.299717'), Decimal('6.00')),
#  ('French Polynesia', 2020, Decimal('100.00'), Decimal('97.00'), Decimal('0.301920'), Decimal('5.71')),
#  ('Niue', 2019, Decimal('97.00'), Decimal('96.00'), None, None),
#  ('Niue', 2020, Decimal('97.00'), Decimal('96.00'), None, None),
#  ('Samoa', 2019, Decimal('92.00'), Decimal('96.33'), Decimal('0.211905'), Decimal('0.91')),
#  ('Samoa', 2020, Decimal('92.00'), Decimal('96.33'), Decimal('0.214929'), Decimal('0.87')),
#  ('Tokelau', 2019, Decimal('100.00'), Decimal('97.00'), None, None),
#  ('Tokelau', 2020, Decimal('100.00'), Decimal('97.00'), None, None),
#  ('Tonga', 2019, Decimal('98.67'), Decimal('93.67'), Decimal('0.104951'), Decimal('0.51')),
#  ('Tonga', 2020, Decimal('99.00'), Decimal('93.33'), Decimal('0.105254'), Decimal('0.48')),
#  ('Tuvalu', 2019, Decimal('100.00'), None, Decimal('0.010956'), Decimal('0.05')),
#  ('Tuvalu', 2020, Decimal('100.00'), None, Decimal('0.011069'), Decimal('0.06')),
#  ('Wallis and Futuna Islands', 2019, Decimal('99.00'), Decimal('93.00'), None, None),
#  ('Wallis and Futuna Islands', 2020, Decimal('99.00'), Decimal('93.00'), None, None),
#  ('Burundi', 2019, Decimal('70.33'), Decimal('44.33'), Decimal('11.874838'), Decimal('2.58')),
#  ('Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('12.220227'), Decimal('2.65')),
#  ('Comoros', 2019, Decimal('81.67'), Decimal('37.67'), Decimal('0.790986'), Decimal('1.20')),
#  ('Djibouti', 2019, Decimal('69.00'), Decimal('56.00'), Decimal('1.073994'), Decimal('3.09')),
#  ('Djibouti', 2020, Decimal('69.00'), Decimal('56.00'), Decimal('1.090156'), Decimal('3.18')),
#  ('Ethiopia', 2019, Decimal('57.00'), Decimal('11.67'), Decimal('114.120594'), Decimal('95.91')),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911'), Decimal('107.66')),
#  ('Kenya', 2019, Decimal('66.33'), Decimal('33.33'), Decimal('50.951450'), Decimal('100.38')),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780'), Decimal('100.67')),
#  ('Madagascar', 2019, Decimal('56.00'), Decimal('12.67'), Decimal('27.533134'), Decimal('14.10')),
#  ('Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('28.225177'), Decimal('13.05')),
#  ('Malawi', 2019, Decimal('73.67'), Decimal('28.33'), Decimal('18.867337'), Decimal('11.03')),
#  ('Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('19.377061'), Decimal('12.18')),
#  ('Mauritius', 2019, Decimal('100.00'), Decimal('96.00'), Decimal('1.265711'), Decimal('14.44')),
#  ('Mauritius', 2020, Decimal('100.00'), Decimal('96.00'), Decimal('1.265740'), Decimal('11.40')),
#  ('Mayotte', 2019, Decimal('96.00'), Decimal('100.00'), None, None),
#  ('Mayotte', 2020, Decimal('96.00'), Decimal('100.00'), None, None),
#  ('Mozambique', 2019, Decimal('64.33'), Decimal('39.33'), Decimal('30.285595'), Decimal('15.39')),
#  ('Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('31.178239'), Decimal('14.03')),
#  ('Rwanda', 2019, Decimal('66.33'), Decimal('64.00'), Decimal('12.835028'), Decimal('10.36')),
#  ('Rwanda', 2020, Decimal('66.33'), Decimal('64.00'), Decimal('13.146362'), Decimal('10.18')),
#  ('Réunion', 2019, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Réunion', 2020, Decimal('100.00'), Decimal('100.00'), None, None),
#  ('Seychelles', 2019, Decimal('97.00'), Decimal('100.00'), Decimal('0.097625'), Decimal('1.68')),
#  ('Somalia', 2019, Decimal('56.33'), Decimal('39.33'), Decimal('15.981300'), Decimal('6.49')),
#  ('Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('16.537016'), Decimal('6.88')),
#  ('South Sudan', 2019, Decimal('48.33'), Decimal('22.33'), Decimal('10.447666'), None),
#  ('South Sudan', 2020, Decimal('48.33'), Decimal('22.33'), Decimal('10.606227'), None),
#  ('Uganda', 2019, Decimal('59.33'), Decimal('21.67'), Decimal('42.949080'), Decimal('35.35')),
#  ('Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('44.404611'), Decimal('37.60')),
#  ('United Republic of Tanzania', 2019, Decimal('64.67'), Decimal('34.00'), None, None),
#  ('United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('34.00'), None, None),
#  ('Zambia', 2019, Decimal('66.33'), Decimal('32.00'), Decimal('18.380477'), Decimal('23.31')),
#  ('Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.927715'), Decimal('18.11')),
#  ('Zimbabwe', 2019, Decimal('68.33'), Decimal('37.00'), Decimal('15.354608'), Decimal('21.83')),
#  ('Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('15.669666'), Decimal('21.51')),
#  ('Angola', 2019, Decimal('52.33'), Decimal('46.67'), Decimal('32.353588'), Decimal('69.31')),
#  ('Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('33.428486'), Decimal('53.62')),
#  ('Cameroon', 2019, Decimal('63.33'), Decimal('42.33'), Decimal('25.782341'), Decimal('39.67')),
#  ('Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('26.491087'), Decimal('40.77')),
#  ('Central African Republic', 2019, Decimal('39.33'), Decimal('15.33'), Decimal('5.209324'), Decimal('2.22')),
#  ('Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('5.343020'), Decimal('2.33')),
#  ('Chad', 2019, Decimal('52.33'), Decimal('18.33'), Decimal('16.126866'), Decimal('11.31')),
#  ('Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('16.644701'), Decimal('10.72')),
#  ('Congo', 2019, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('Democratic Republic of the Congo', 2019, Decimal('47.00'), Decimal('16.33'), None, None),
#  ('Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('15.33'), None, None),
#  ('Gabon', 2019, Decimal('73.33'), Decimal('47.00'), Decimal('2.242785'), Decimal('16.87')),
#  ('Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('2.292573'), Decimal('15.31')),
#  ('Sao Tome and Principe', 2019, Decimal('77.33'), Decimal('44.33'), Decimal('0.214599'), Decimal('0.43')),
#  ('Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.218641'), Decimal('0.47')),
#  ('Botswana', 2019, Decimal('89.67'), Decimal('74.33'), Decimal('2.499702'), Decimal('16.70')),
#  ('Botswana', 2020, Decimal('89.67'), Decimal('74.33'), Decimal('2.546402'), Decimal('14.93')),
#  ('Eswatini', 2019, Decimal('76.67'), Decimal('61.33'), Decimal('1.169613'), Decimal('4.50')),
#  ('Eswatini', 2020, Decimal('76.67'), Decimal('61.33'), Decimal('1.180655'), Decimal('3.98')),
#  ('Lesotho', 2019, Decimal('76.00'), Decimal('47.67'), Decimal('2.225702'), Decimal('2.45')),
#  ('Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.254100'), Decimal('2.23')),
#  ('Namibia', 2019, Decimal('83.67'), Decimal('35.00'), Decimal('2.446644'), Decimal('12.54')),
#  ('Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('2.489098'), Decimal('10.58')),
#  ('South Africa', 2019, Decimal('91.67'), Decimal('78.00'), Decimal('58.087055'), Decimal('388.53')),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('58.801927'), Decimal('337.62')),
#  ('Benin', 2019, Decimal('65.33'), Decimal('17.00'), Decimal('12.290444'), Decimal('14.39')),
#  ('Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('12.643123'), Decimal('15.65')),
#  ('Burkina Faso', 2019, Decimal('54.00'), Decimal('25.00'), Decimal('20.951639'), Decimal('16.18')),
#  ('Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('21.522626'), Decimal('17.93')),
#  ('Cabo Verde', 2019, Decimal('86.67'), Decimal('76.00'), Decimal('0.577030'), Decimal('1.98')),
#  ('Cabo Verde', 2020, Decimal('87.33'), Decimal('78.00'), Decimal('0.582640'), Decimal('1.70')),
#  ("Côte d'Ivoire", 2019, Decimal('70.67'), Decimal('33.67'), None, None),
#  ("Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('34.67'), None, None),
#  ('Gambia', 2019, Decimal('79.33'), Decimal('44.33'), None, None),
#  ('Gambia', 2020, Decimal('79.33'), Decimal('44.33'), None, None),
#  ('Ghana', 2019, Decimal('83.67'), Decimal('22.67'), Decimal('31.522290'), Decimal('68.34')),
#  ('Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('32.180401'), Decimal('70.04')),
#  ('Guinea', 2019, Decimal('67.00'), Decimal('30.67'), Decimal('12.877539'), Decimal('13.44')),
#  ('Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('13.205153'), Decimal('14.18')),
#  ('Guinea-Bissau', 2019, Decimal('60.00'), Decimal('18.33'), Decimal('1.970457'), Decimal('1.44')),
#  ('Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('2.015828'), Decimal('1.43')),
#  ('Liberia', 2019, Decimal('75.00'), Decimal('17.67'), Decimal('4.985289'), Decimal('3.32')),
#  ('Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('5.087584'), Decimal('3.04')),
#  ('Mali', 2019, Decimal('82.00'), Decimal('44.67'), Decimal('20.567424'), Decimal('17.28')),
#  ('Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('21.224040'), Decimal('17.47')),
#  ('Mauritania', 2019, Decimal('70.00'), Decimal('47.67'), Decimal('4.383849'), Decimal('8.07')),
#  ('Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('4.498604'), Decimal('8.41')),
#  ('Niger', 2019, Decimal('57.33'), Decimal('23.67'), Decimal('23.443393'), Decimal('12.92')),
#  ('Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('24.333639'), Decimal('13.74')),
#  ('Nigeria', 2019, Decimal('75.67'), Decimal('41.67'), Decimal('203.304492'), Decimal('448.12')),
#  ('Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('208.327405'), Decimal('432.20')),
#  ('Saint Helena', 2019, Decimal('99.00'), Decimal('100.00'), None, None),
#  ('Saint Helena', 2020, Decimal('99.00'), Decimal('100.00'), None, None),
#  ('Senegal', 2019, Decimal('84.00'), Decimal('56.33'), Decimal('16.000781'), Decimal('23.40')),
#  ('Senegal', 2020, Decimal('85.00'), Decimal('57.00'), Decimal('16.436120'), Decimal('24.49')),
#  ('Sierra Leone', 2019, Decimal('64.00'), Decimal('17.00'), Decimal('8.046828'), Decimal('4.08')),
#  ('Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('8.233970'), Decimal('4.06')),
#  ('Togo', 2019, Decimal('70.33'), Decimal('19.67'), Decimal('8.243094'), Decimal('7.22')),
#  ('Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('8.442580'), Decimal('7.57'))]

# %% [markdown]
# ### Task 2: Streamlining with the IN Operator
#
# Building on the first task, you might have noticed that using multiple `OR` operators can make the query lengthy and a bit complicated. The 'IN' operator offers a more efficient way to achieve the same result.
# The `IN` operator allows you to specify multiple values in a `WHERE` clause, making the query more concise.
# Try to retrieve data for the same list of countries for the same time range, but this time, use the `IN` operator to simplify your query.

# %%
# %%sql
# -- Add your code here
# SELECT Country_name, Time_period, Pct_managed_drinking_water_services, Pct_managed_sanitation_services, Est_population_in_millions, Est_gdp_in_billions
# FROM united_nations.Access_to_Basic_Services
# WHERE Country_name IN ('Nigeria', 'Ethiopia', 'Congo', 'Egypt', 'Tanzania', 'Kenya', 'South Africa')
# AND Time_period BETWEEN 2019 AND 2020;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 12 rows affected.
# [('Egypt', 2019, Decimal('99.33'), Decimal('97.00'), None, None),
#  ('Egypt', 2020, Decimal('99.33'), Decimal('97.67'), None, None),
#  ('Ethiopia', 2019, Decimal('57.00'), Decimal('11.67'), Decimal('114.120594'), Decimal('95.91')),
#  ('Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911'), Decimal('107.66')),
#  ('Kenya', 2019, Decimal('66.33'), Decimal('33.33'), Decimal('50.951450'), Decimal('100.38')),
#  ('Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780'), Decimal('100.67')),
#  ('Congo', 2019, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('South Africa', 2019, Decimal('91.67'), Decimal('78.00'), Decimal('58.087055'), Decimal('388.53')),
#  ('South Africa', 2020, Decimal('92.00'), Decimal('78.67'), Decimal('58.801927'), Decimal('337.62')),
#  ('Nigeria', 2019, Decimal('75.67'), Decimal('41.67'), Decimal('203.304492'), Decimal('448.12')),
#  ('Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('208.327405'), Decimal('432.20'))]

# %% [markdown]
# ### Task 3: Combining Multiple Conditions
#
# The `<=` operator is a comparison operator that checks if the value on the left is less than or equal to the value on the right. In this task, you'll use it to filter countries based on specific service percentages.
# You'll continue working with the `united_nations.Access_to_Basic_Services` table.
# The columns to be selected for this task are
# - `Region`,
# - `Country_name`,
# - `Time_period`,
# - `Pct_managed_drinking_water_services`,
# - `Pct_managed_sanitation_services`,
# - `Est_population_in_millions`, and
# - `Est_gdp_in_billions`.
#
# Your goal is to extract data for the year 2020, focusing on countries where less than or equal to 50% of the population has access to sanitation services. This will help identify countries with critical sanitation needs.
# By using the `<=` operator with the `Pct_managed_sanitation_services` column, you can filter out countries that exceed this threshold, leaving only those with the most pressing sanitation challenges.

# %%
# %%sql
# -- Add your code here
# SELECT Region, Country_name, Time_period, Pct_managed_drinking_water_services, Pct_managed_sanitation_services, Est_population_in_millions, Est_gdp_in_billions
# FROM united_nations.Access_to_Basic_Services
# WHERE Time_period = 2020
# AND Pct_managed_sanitation_services <= 50;
# Out:
#  * mysql+pymysql://root:***@localhost:3306/united_nations
# 41 rows affected.
# [('Latin America and the Caribbean', 'Haiti', 2020, Decimal('65.00'), Decimal('36.00'), Decimal('11.306801'), Decimal('14.51')),
#  ('Northern Africa and Western Asia', 'Sudan', 2020, Decimal('62.33'), Decimal('40.33'), Decimal('44.440486'), Decimal('27.03')),
#  ('Oceania', 'Papua New Guinea', 2020, Decimal('56.67'), Decimal('27.67'), Decimal('9.749640'), Decimal('23.85')),
#  ('Oceania', 'Solomon Islands', 2020, Decimal('72.33'), Decimal('44.67'), Decimal('0.691191'), Decimal('1.54')),
#  ('Oceania', 'Kiribati', 2020, Decimal('77.00'), Decimal('45.33'), Decimal('0.126463'), Decimal('0.18')),
#  ('Sub-Saharan Africa', 'Burundi', 2020, Decimal('70.33'), Decimal('44.33'), Decimal('12.220227'), Decimal('2.65')),
#  ('Sub-Saharan Africa', 'Ethiopia', 2020, Decimal('58.00'), Decimal('11.67'), Decimal('117.190911'), Decimal('107.66')),
#  ('Sub-Saharan Africa', 'Kenya', 2020, Decimal('67.00'), Decimal('33.67'), Decimal('51.985780'), Decimal('100.67')),
#  ('Sub-Saharan Africa', 'Madagascar', 2020, Decimal('56.33'), Decimal('13.00'), Decimal('28.225177'), Decimal('13.05')),
#  ('Sub-Saharan Africa', 'Malawi', 2020, Decimal('74.33'), Decimal('28.67'), Decimal('19.377061'), Decimal('12.18')),
#  ('Sub-Saharan Africa', 'Mozambique', 2020, Decimal('66.67'), Decimal('40.33'), Decimal('31.178239'), Decimal('14.03')),
#  ('Sub-Saharan Africa', 'Somalia', 2020, Decimal('57.33'), Decimal('40.00'), Decimal('16.537016'), Decimal('6.88')),
#  ('Sub-Saharan Africa', 'South Sudan', 2020, Decimal('48.33'), Decimal('22.33'), Decimal('10.606227'), None),
#  ('Sub-Saharan Africa', 'Uganda', 2020, Decimal('61.00'), Decimal('21.67'), Decimal('44.404611'), Decimal('37.60')),
#  ('Sub-Saharan Africa', 'United Republic of Tanzania', 2020, Decimal('65.00'), Decimal('34.00'), None, None),
#  ('Sub-Saharan Africa', 'Zambia', 2020, Decimal('66.67'), Decimal('32.67'), Decimal('18.927715'), Decimal('18.11')),
#  ('Sub-Saharan Africa', 'Zimbabwe', 2020, Decimal('68.00'), Decimal('36.33'), Decimal('15.669666'), Decimal('21.51')),
#  ('Sub-Saharan Africa', 'Angola', 2020, Decimal('52.33'), Decimal('47.00'), Decimal('33.428486'), Decimal('53.62')),
#  ('Sub-Saharan Africa', 'Cameroon', 2020, Decimal('64.00'), Decimal('43.00'), Decimal('26.491087'), Decimal('40.77')),
#  ('Sub-Saharan Africa', 'Central African Republic', 2020, Decimal('38.33'), Decimal('15.00'), Decimal('5.343020'), Decimal('2.33')),
#  ('Sub-Saharan Africa', 'Chad', 2020, Decimal('52.67'), Decimal('18.67'), Decimal('16.644701'), Decimal('10.72')),
#  ('Sub-Saharan Africa', 'Congo', 2020, Decimal('69.00'), Decimal('17.67'), None, None),
#  ('Sub-Saharan Africa', 'Democratic Republic of the Congo', 2020, Decimal('47.67'), Decimal('15.33'), None, None),
#  ('Sub-Saharan Africa', 'Gabon', 2020, Decimal('73.33'), Decimal('47.00'), Decimal('2.292573'), Decimal('15.31')),
#  ('Sub-Saharan Africa', 'Sao Tome and Principe', 2020, Decimal('77.33'), Decimal('46.00'), Decimal('0.218641'), Decimal('0.47')),
#  ('Sub-Saharan Africa', 'Lesotho', 2020, Decimal('76.33'), Decimal('49.67'), Decimal('2.254100'), Decimal('2.23')),
#  ('Sub-Saharan Africa', 'Namibia', 2020, Decimal('83.67'), Decimal('35.00'), Decimal('2.489098'), Decimal('10.58')),
#  ('Sub-Saharan Africa', 'Benin', 2020, Decimal('65.33'), Decimal('17.33'), Decimal('12.643123'), Decimal('15.65')),
#  ('Sub-Saharan Africa', 'Burkina Faso', 2020, Decimal('53.33'), Decimal('25.00'), Decimal('21.522626'), Decimal('17.93')),
#  ('Sub-Saharan Africa', "Côte d'Ivoire", 2020, Decimal('70.67'), Decimal('34.67'), None, None),
#  ('Sub-Saharan Africa', 'Gambia', 2020, Decimal('79.33'), Decimal('44.33'), None, None),
#  ('Sub-Saharan Africa', 'Ghana', 2020, Decimal('84.67'), Decimal('23.00'), Decimal('32.180401'), Decimal('70.04')),
#  ('Sub-Saharan Africa', 'Guinea', 2020, Decimal('67.33'), Decimal('32.33'), Decimal('13.205153'), Decimal('14.18')),
#  ('Sub-Saharan Africa', 'Guinea-Bissau', 2020, Decimal('60.00'), Decimal('19.33'), Decimal('2.015828'), Decimal('1.43')),
#  ('Sub-Saharan Africa', 'Liberia', 2020, Decimal('75.00'), Decimal('17.67'), Decimal('5.087584'), Decimal('3.04')),
#  ('Sub-Saharan Africa', 'Mali', 2020, Decimal('83.67'), Decimal('46.00'), Decimal('21.224040'), Decimal('17.47')),
#  ('Sub-Saharan Africa', 'Mauritania', 2020, Decimal('70.33'), Decimal('48.00'), Decimal('4.498604'), Decimal('8.41')),
#  ('Sub-Saharan Africa', 'Niger', 2020, Decimal('57.33'), Decimal('24.67'), Decimal('24.333639'), Decimal('13.74')),
#  ('Sub-Saharan Africa', 'Nigeria', 2020, Decimal('77.33'), Decimal('42.67'), Decimal('208.327405'), Decimal('432.20')),
#  ('Sub-Saharan Africa', 'Sierra Leone', 2020, Decimal('65.00'), Decimal('17.33'), Decimal('8.233970'), Decimal('4.06')),
#  ('Sub-Saharan Africa', 'Togo', 2020, Decimal('70.67'), Decimal('20.00'), Decimal('8.442580'), Decimal('7.57'))]

# %% [markdown]
# ## Solutions
#
# ### Task 1: Basic Filtering with Comparison Operators

# %%
SELECT 
Country_name, 	 
Time_period, 
Pct_managed_drinking_water_services, 
Pct_managed_sanitation_services, 
Est_population_in_millions,
Est_gdp_in_billions  
FROM 
united_nations.Access_to_Basic_Services 
WHERE 
Country_name = 'Nigeria' 
OR Country_name = 'Ethiopia' 
OR Country_name = 'Congo' 
OR Country_name = 'Egypt' 
OR Country_name = 'Tanzania' 
OR Country_name = 'Kenya' 
OR Country_name ='South Africa'
AND Time_period BETWEEN 2019 AND 2020;

# %% [markdown]
# ### Task 2: Streamlining with the IN Operator

# %%
# %%sql
# SELECT
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Country_name IN (
#         'Nigeria',
#         'Ethiopia' ,
#         'Congo',
#         'Egypt',
#         'Tanzania',
#         'Kenya',
#         'South Africa'
#  )
# AND Time_period BETWEEN 2019 AND 2020;

# %% [markdown]
# ### Task 3: Combining Multiple Conditions

# %%
# %%sql
# SELECT
# Region,
# Country_name,
# Time_period,
# Pct_managed_drinking_water_services,
# Pct_managed_sanitation_services,
# Est_population_in_millions,
# Est_gdp_in_billions
# FROM
# united_nations.Access_to_Basic_Services
# WHERE
# Time_period = 2020
# AND Pct_managed_sanitation_services <= 50;

# %% [markdown]
# <div align="center" style=" font-size: 80%; text-align: center; margin: 0 auto">
# <img src="https://raw.githubusercontent.com/Explore-AI/Pictures/master/ExploreAI_logos/EAI_Blue_Dark.png"  style="width:200px";/>
# </div>
